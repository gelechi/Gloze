# %% [markdown]
# <a href="https://colab.research.google.com/github/gelechi/Gloze/blob/main/Copy_of_cours_32_graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df = sns.load_dataset("mpg")
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
## Let's convert to metric style

# lbs to tons (1000 kg)
df['weight'] = df['weight'] * 0.4536 / 1000
# mpg to l/100km
df['fuel_consumption'] = 235.215 / df['mpg']
# cubic inches to liter
df['displacement'] = df['displacement'] * 0.0164

# %%
# All possible lines

x = df['weight']
y = df['fuel_consumption']

fig = go.Figure()
fig.add_trace(go.Scatter(name='', x=x, y=y, mode='markers')) #, range_x=(0,6000), range_y=(0, 50), width=800, height=500))

# Add regression line
intercept = -0.1
coef = 9
color = 'darkorchid'
x_line = x
y_line = intercept + coef*x_line,
fig.add_trace(go.Scatter(name='', x=x_line, y=intercept + coef*x_line, mode='lines', line=dict(color=color, dash='dash')))

# Too low
intercept = 0
coef = 6
color = 'green'
x_line = x
y_line = intercept + coef*x_line,
fig.add_trace(go.Scatter(name='', x=x_line, y=intercept + coef*x_line, mode='lines', line=dict(color=color, dash='dash')))

# Too high
intercept = 0
coef = 12
color = 'orange'
x_line = x
y_line = intercept + coef*x_line,
fig.add_trace(go.Scatter(name='', x=x_line, y=intercept + coef*x_line, mode='lines', line=dict(color=color, dash='dash')))

fig.update_layout(xaxis_title='weight (1000 kg)', yaxis_title='fuel consumption (l/100km)')
fig.update_layout(autosize=False, width=700, height=500)
fig.update_layout(legend=dict(visible=False))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9955e1df-d45c-49c5-b0b3-acb8dcebd42c" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9955e1df-d45c-49c5-b0b3-acb8dcebd42c")) {                    Plotly.newPlot(                        "9955e1df-d45c-49c5-b0b3-acb8dcebd42c",                        [{"mode":"markers","name":"","x":[1.5894144000000001,1.6751448,1.5585696,1.5572088000000002,1.5644664,1.9690776,1.9749744,1.9559232,2.00718,1.74636,1.6161767999999999,1.6370424000000001,1.7059896,1.3998096,1.0759392,1.2850488,1.2582864,1.1734631999999998,0.966168,0.832356,1.2120191999999999,1.1022480000000001,1.0773,1.0133424,1.2011328000000001,2.0933640000000002,1.9849536,1.9876752,2.1464352,0.966168,1.0269504,1.0106208,0.9280656,1.1947824,1.5599304,1.5100344,1.4977871999999999,1.4914368,1.9092024,2.0248704,1.8842544,1.8579456,2.2475880000000004,2.1527856,2.331504,1.3435632,1.0922688,1.4887152000000001,1.4238504,1.0069919999999999,0.9629928,0.9407664,0.936684,0.8042328,0.7316568,0.8319024,0.886788,1.0333008,0.9643536,1.0224144,1.0922688,1.0097136,1.9386864000000001,1.989036,1.8756359999999999,1.8729144000000002,1.6656192,2.1015288,2.0421072,2.0212416,2.0058192,1.0568879999999998,1.7654112,1.8588528000000002,1.9477584,1.8493271999999998,1.3304087999999998,1.1389896000000002,1.3512744,0.9929304,1.0863720000000001,1.0378368,1.1367216,0.9815904000000001,0.9525600000000001,1.85976,1.6656192,1.8089568,1.8334512,1.7132472,2.2462272,2.0248704,1.9790568000000002,1.9219032,2.147796,2.2457736,1.7332056,1.4156856,1.4869008000000001,1.335852,1.3703256000000001,1.3172544,0.88452,2.2666392,2.2253616000000003,2.1110544,2.0407464,1.2650904,1.0337544,1.0890936,1.0791144,0.9634464,1.047816,1.1212992,1.027404,1.8515952,1.9405008000000001,0.8468712,0.9788688,1.1711952,1.3009248,1.5417864,1.206576,1.2732552000000001,1.6619903999999999,1.4070672,1.3040999999999998,1.3158936,1.5132096,0.88452,1.1117736,0.8328096,1.1530512000000002,1.7150616,1.6474752000000001,1.6388568000000001,1.8783576,2.1314664,2.0216952,2.1037968,1.9309752,1.0065384,0.8904168,1.04328,0.7479864,0.9085608,0.9639,0.9561888000000001,1.0187856,1.1290104,1.0845576000000001,0.9072,1.4805504,1.5690024,1.5567552,1.4324688,2.1174047999999996,2.0139839999999998,2.0402928,2.1124152,1.7722152,1.7676792000000001,1.691928,1.716876,1.3784904,1.4610455999999998,1.4374584,0.9847656,1.1970504000000002,1.3217904,1.1757312,1.2256272,1.0083528,1.154412,1.3535424,0.8786232,1.4565096000000002,1.2219984,1.3412952,1.335852,1.2115656,0.8142119999999999,1.1176704,1.0069919999999999,1.1666592,1.022868,0.9988272,1.911924,1.900584,1.7971632,1.911924,1.4664888,1.5209208,1.3662432000000002,1.399356,0.923076,0.9815904000000001,0.8786232,0.8142119999999999,1.6560936,1.6211664000000001,1.653372,1.4483448,0.82782,0.902664,0.977508,1.163484,1.4288399999999999,1.7871839999999999,1.483272,1.329048,1.7327519999999998,1.986768,1.839348,1.755432,1.703268,0.927612,0.977508,0.82782,1.04328,0.8822519999999999,1.759968,1.841616,1.877904,1.948212,1.596672,1.55358,1.646568,1.59894,1.9141920000000001,1.889244,1.96182,1.966356,0.879984,1.242864,1.027404,1.2496680000000002,0.9303336000000001,0.9412200000000001,0.900396,0.993384,1.276884,1.17936,1.233792,0.900396,0.81648,0.900396,0.938952,0.81648,1.526364,1.6941959999999998,1.6193520000000001,1.6034760000000001,1.431108,1.344924,1.233792,1.555848,1.456056,1.533168,1.392552,1.642032,1.5467760000000002,1.55358,1.5626520000000002,1.453788,1.850688,0.977508,1.1612159999999998,1.04328,1.011528,1.1408040000000002,1.2451320000000001,1.295028,1.090908,1.2836880000000002,1.424304,1.267812,1.5467760000000002,0.902664,0.9684360000000001,1.471932,1.356264,1.310904,1.481004,1.524096,1.741824,1.6896600000000002,1.7939880000000001,1.737288,1. ...

# %%
# With error bars

intercept = -0.1
coef = 9
color = 'darkorchid'

# Too low
# intercept = 0
# coef = 6
# color = 'green'

# Too high
# intercept = 0
# coef = 12
# color = 'orange'

x = df['weight']
y = df['fuel_consumption']
x_line = df['weight'].copy()
y_line = intercept + coef*x_line,

fig = go.Figure()
fig.add_trace(go.Scatter(name='', x=x, y=y, mode='markers')) #, range_x=(0,6000), range_y=(0, 50), width=800, height=500))

# Add regression line
fig.add_trace(go.Scatter(name='', x=x_line, y=intercept + coef*x_line, mode='lines', line=dict(color=color, dash='dash')))

# Add error bars
x_vals = fig.data[0]['x']
errors = {d['mode']: d['y'] for d in fig.data}
shapes = []
for i, x in enumerate(x_vals):
    shapes.append(go.layout.Shape(type="line",
                                    x0=x,
                                    y0=errors['markers'][i],
                                    x1=x,
                                    y1=errors['lines'][i],
                                    line=dict(
                                        color='black',
                                        width=1),
                                    opacity=0.5,
                                    layer="above")
                 )
# fig.update_layout(shapes=shapes)

fig.update_layout(xaxis_title='weight (1000 kg)', yaxis_title='fuel consumption (l/100km)')
fig.update_layout(autosize=False, width=700, height=500)
fig.update_layout(legend=dict(visible=False))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bcb4ae04-3e03-4616-ae20-58f554c7c949" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcb4ae04-3e03-4616-ae20-58f554c7c949")) {                    Plotly.newPlot(                        "bcb4ae04-3e03-4616-ae20-58f554c7c949",                        [{"mode":"markers","name":"","x":[1.5894144000000001,1.6751448,1.5585696,1.5572088000000002,1.5644664,1.9690776,1.9749744,1.9559232,2.00718,1.74636,1.6161767999999999,1.6370424000000001,1.7059896,1.3998096,1.0759392,1.2850488,1.2582864,1.1734631999999998,0.966168,0.832356,1.2120191999999999,1.1022480000000001,1.0773,1.0133424,1.2011328000000001,2.0933640000000002,1.9849536,1.9876752,2.1464352,0.966168,1.0269504,1.0106208,0.9280656,1.1947824,1.5599304,1.5100344,1.4977871999999999,1.4914368,1.9092024,2.0248704,1.8842544,1.8579456,2.2475880000000004,2.1527856,2.331504,1.3435632,1.0922688,1.4887152000000001,1.4238504,1.0069919999999999,0.9629928,0.9407664,0.936684,0.8042328,0.7316568,0.8319024,0.886788,1.0333008,0.9643536,1.0224144,1.0922688,1.0097136,1.9386864000000001,1.989036,1.8756359999999999,1.8729144000000002,1.6656192,2.1015288,2.0421072,2.0212416,2.0058192,1.0568879999999998,1.7654112,1.8588528000000002,1.9477584,1.8493271999999998,1.3304087999999998,1.1389896000000002,1.3512744,0.9929304,1.0863720000000001,1.0378368,1.1367216,0.9815904000000001,0.9525600000000001,1.85976,1.6656192,1.8089568,1.8334512,1.7132472,2.2462272,2.0248704,1.9790568000000002,1.9219032,2.147796,2.2457736,1.7332056,1.4156856,1.4869008000000001,1.335852,1.3703256000000001,1.3172544,0.88452,2.2666392,2.2253616000000003,2.1110544,2.0407464,1.2650904,1.0337544,1.0890936,1.0791144,0.9634464,1.047816,1.1212992,1.027404,1.8515952,1.9405008000000001,0.8468712,0.9788688,1.1711952,1.3009248,1.5417864,1.206576,1.2732552000000001,1.6619903999999999,1.4070672,1.3040999999999998,1.3158936,1.5132096,0.88452,1.1117736,0.8328096,1.1530512000000002,1.7150616,1.6474752000000001,1.6388568000000001,1.8783576,2.1314664,2.0216952,2.1037968,1.9309752,1.0065384,0.8904168,1.04328,0.7479864,0.9085608,0.9639,0.9561888000000001,1.0187856,1.1290104,1.0845576000000001,0.9072,1.4805504,1.5690024,1.5567552,1.4324688,2.1174047999999996,2.0139839999999998,2.0402928,2.1124152,1.7722152,1.7676792000000001,1.691928,1.716876,1.3784904,1.4610455999999998,1.4374584,0.9847656,1.1970504000000002,1.3217904,1.1757312,1.2256272,1.0083528,1.154412,1.3535424,0.8786232,1.4565096000000002,1.2219984,1.3412952,1.335852,1.2115656,0.8142119999999999,1.1176704,1.0069919999999999,1.1666592,1.022868,0.9988272,1.911924,1.900584,1.7971632,1.911924,1.4664888,1.5209208,1.3662432000000002,1.399356,0.923076,0.9815904000000001,0.8786232,0.8142119999999999,1.6560936,1.6211664000000001,1.653372,1.4483448,0.82782,0.902664,0.977508,1.163484,1.4288399999999999,1.7871839999999999,1.483272,1.329048,1.7327519999999998,1.986768,1.839348,1.755432,1.703268,0.927612,0.977508,0.82782,1.04328,0.8822519999999999,1.759968,1.841616,1.877904,1.948212,1.596672,1.55358,1.646568,1.59894,1.9141920000000001,1.889244,1.96182,1.966356,0.879984,1.242864,1.027404,1.2496680000000002,0.9303336000000001,0.9412200000000001,0.900396,0.993384,1.276884,1.17936,1.233792,0.900396,0.81648,0.900396,0.938952,0.81648,1.526364,1.6941959999999998,1.6193520000000001,1.6034760000000001,1.431108,1.344924,1.233792,1.555848,1.456056,1.533168,1.392552,1.642032,1.5467760000000002,1.55358,1.5626520000000002,1.453788,1.850688,0.977508,1.1612159999999998,1.04328,1.011528,1.1408040000000002,1.2451320000000001,1.295028,1.090908,1.2836880000000002,1.424304,1.267812,1.5467760000000002,0.902664,0.9684360000000001,1.471932,1.356264,1.310904,1.481004,1.524096,1.741824,1.6896600000000002,1.7939880000000001,1.737288,1. ...

# %%
# Best model, with intercept shown

intercept = -0.1
coef = 9
color = 'darkorchid'

x = df['weight']
y = df['fuel_consumption']
x_line = pd.concat([pd.Series([0], index=[-1]), x, pd.Series([3],index=[398])], axis=0)
y_line = intercept + coef*x_line,

fig = go.Figure()
fig.add_trace(go.Scatter(name='', x=x, y=y, mode='markers')) #, range_x=(0,6000), range_y=(0, 50), width=800, height=500))

# Add regression line
fig.add_trace(go.Scatter(name='', x=x_line, y=intercept + coef*x_line, mode='lines', line=dict(color=color, dash='dash')))

fig.update_layout(xaxis_title='weight (1000 kg)', yaxis_title='fuel consumption (l/100km)')
fig.update_layout(autosize=False, width=700, height=500)
fig.update_layout(legend=dict(visible=False))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d389b687-a50d-40b1-b0dd-8494a058633d" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d389b687-a50d-40b1-b0dd-8494a058633d")) {                    Plotly.newPlot(                        "d389b687-a50d-40b1-b0dd-8494a058633d",                        [{"mode":"markers","name":"","x":[1.5894144000000001,1.6751448,1.5585696,1.5572088000000002,1.5644664,1.9690776,1.9749744,1.9559232,2.00718,1.74636,1.6161767999999999,1.6370424000000001,1.7059896,1.3998096,1.0759392,1.2850488,1.2582864,1.1734631999999998,0.966168,0.832356,1.2120191999999999,1.1022480000000001,1.0773,1.0133424,1.2011328000000001,2.0933640000000002,1.9849536,1.9876752,2.1464352,0.966168,1.0269504,1.0106208,0.9280656,1.1947824,1.5599304,1.5100344,1.4977871999999999,1.4914368,1.9092024,2.0248704,1.8842544,1.8579456,2.2475880000000004,2.1527856,2.331504,1.3435632,1.0922688,1.4887152000000001,1.4238504,1.0069919999999999,0.9629928,0.9407664,0.936684,0.8042328,0.7316568,0.8319024,0.886788,1.0333008,0.9643536,1.0224144,1.0922688,1.0097136,1.9386864000000001,1.989036,1.8756359999999999,1.8729144000000002,1.6656192,2.1015288,2.0421072,2.0212416,2.0058192,1.0568879999999998,1.7654112,1.8588528000000002,1.9477584,1.8493271999999998,1.3304087999999998,1.1389896000000002,1.3512744,0.9929304,1.0863720000000001,1.0378368,1.1367216,0.9815904000000001,0.9525600000000001,1.85976,1.6656192,1.8089568,1.8334512,1.7132472,2.2462272,2.0248704,1.9790568000000002,1.9219032,2.147796,2.2457736,1.7332056,1.4156856,1.4869008000000001,1.335852,1.3703256000000001,1.3172544,0.88452,2.2666392,2.2253616000000003,2.1110544,2.0407464,1.2650904,1.0337544,1.0890936,1.0791144,0.9634464,1.047816,1.1212992,1.027404,1.8515952,1.9405008000000001,0.8468712,0.9788688,1.1711952,1.3009248,1.5417864,1.206576,1.2732552000000001,1.6619903999999999,1.4070672,1.3040999999999998,1.3158936,1.5132096,0.88452,1.1117736,0.8328096,1.1530512000000002,1.7150616,1.6474752000000001,1.6388568000000001,1.8783576,2.1314664,2.0216952,2.1037968,1.9309752,1.0065384,0.8904168,1.04328,0.7479864,0.9085608,0.9639,0.9561888000000001,1.0187856,1.1290104,1.0845576000000001,0.9072,1.4805504,1.5690024,1.5567552,1.4324688,2.1174047999999996,2.0139839999999998,2.0402928,2.1124152,1.7722152,1.7676792000000001,1.691928,1.716876,1.3784904,1.4610455999999998,1.4374584,0.9847656,1.1970504000000002,1.3217904,1.1757312,1.2256272,1.0083528,1.154412,1.3535424,0.8786232,1.4565096000000002,1.2219984,1.3412952,1.335852,1.2115656,0.8142119999999999,1.1176704,1.0069919999999999,1.1666592,1.022868,0.9988272,1.911924,1.900584,1.7971632,1.911924,1.4664888,1.5209208,1.3662432000000002,1.399356,0.923076,0.9815904000000001,0.8786232,0.8142119999999999,1.6560936,1.6211664000000001,1.653372,1.4483448,0.82782,0.902664,0.977508,1.163484,1.4288399999999999,1.7871839999999999,1.483272,1.329048,1.7327519999999998,1.986768,1.839348,1.755432,1.703268,0.927612,0.977508,0.82782,1.04328,0.8822519999999999,1.759968,1.841616,1.877904,1.948212,1.596672,1.55358,1.646568,1.59894,1.9141920000000001,1.889244,1.96182,1.966356,0.879984,1.242864,1.027404,1.2496680000000002,0.9303336000000001,0.9412200000000001,0.900396,0.993384,1.276884,1.17936,1.233792,0.900396,0.81648,0.900396,0.938952,0.81648,1.526364,1.6941959999999998,1.6193520000000001,1.6034760000000001,1.431108,1.344924,1.233792,1.555848,1.456056,1.533168,1.392552,1.642032,1.5467760000000002,1.55358,1.5626520000000002,1.453788,1.850688,0.977508,1.1612159999999998,1.04328,1.011528,1.1408040000000002,1.2451320000000001,1.295028,1.090908,1.2836880000000002,1.424304,1.267812,1.5467760000000002,0.902664,0.9684360000000001,1.471932,1.356264,1.310904,1.481004,1.524096,1.741824,1.6896600000000002,1.7939880000000001,1.737288,1. ...

# %% [markdown]
# ## Data Cleaning

# %%
from sklearn.impute import SimpleImputer

# Imputer the mean where we don't have data
imputer = SimpleImputer(strategy='mean')
df['horsepower'] = imputer.fit_transform(df[['horsepower']])
df.isnull().sum()
# Out:
# mpg                 0
# cylinders           0
# displacement        0
# horsepower          0
# weight              0
# acceleration        0
# model_year          0
# origin              0
# name                0
# fuel_consumption    0
# dtype: int64

# %% [markdown]
# # Linear Regression with One Features

# %%
X = df[['weight']]
y = df['fuel_consumption']

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
np.round(reg.coef_, 3)
# Out:
# array([8.992])

# %%
np.round(reg.intercept_,3)
# Out:
# -0.903

# %% [markdown]
# # Linear Regression with Multiple Features

# %%
X = df[['weight',
        'displacement',
        'horsepower',]]
y = df['fuel_consumption']

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([5.35754041, 0.22512794, 0.03154875])

# %%
reg.intercept_
# Out:
# -0.01561755823265365
